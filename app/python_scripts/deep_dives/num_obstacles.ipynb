# %%
# this is for the data from a random initial configuration
# with a varying number of exits (1-8)

# imports and reading csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.gridspec import GridSpec

import os
import sys

#get correct path for files
__file__ = 'num_obstacles'
absolutepath = os.path.abspath(__file__)
print(absolutepath) #should be MQP/app/python_scripts/deep_dives/num_obstacles
fileDirectory = os.path.dirname(absolutepath)
print(fileDirectory) #should be MQP/app/python_scripts/deep_dives
#Path of parent directory
parentDirectory = os.path.dirname(fileDirectory)
print(parentDirectory) #should be MQP/app/python_scripts
appDirectory = os.path.dirname(parentDirectory)
print(appDirectory) #should be MQP/app
#Navigate to all_data directory
all_data = os.path.join(appDirectory, 'all_data') #the directory going to, change if something different
print(all_data) #should be MQP/app/all_data
pathOutput6 = os.path.join(all_data, 'data_6.csv') #the file reading from, change if something different
print(pathOutput6) #should be MQP/app/all_data/data_6.csv

data = pd.read_csv(pathOutput6)
# Out:
# /Users/victoriamirecki/Downloads/MQP/app/python_scripts/deep_dives/num_obstacles
# /Users/victoriamirecki/Downloads/MQP/app/python_scripts/deep_dives
# /Users/victoriamirecki/Downloads/MQP/app/python_scripts
# /Users/victoriamirecki/Downloads/MQP/app
# /Users/victoriamirecki/Downloads/MQP/app/all_data
# /Users/victoriamirecki/Downloads/MQP/app/all_data/data_6.csv

# %%
# general initializations
x1=data['max[Obstacle]']
x2=[0,50,100,150,200,250,300]
y1=data['total_exit_time']
y3=data['avg_exit_time']
y5=data['avg_collisions_total']
y7=data['total_avg_occ_all_time']
y9=data['evaluation_metric']

# %%
# y2 initializations
y2=[]
y2e=[]
list_1 = []
avg_1=0
list_2 = []
avg_2=0
list_3 = []
avg_3=0
list_4 = []
avg_4=0
list_5 = []
avg_5=0
list_6 = []
avg_6=0
list_7 = []
avg_7=0

for ind in data.index:
    if(data['max[Obstacle]'][ind] == 0):
        list_1.append(data['total_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 50):
        list_2.append(data['total_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 100):
        list_3.append(data['total_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 150):
        list_4.append(data['total_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 200):
        list_5.append(data['total_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 250):
        list_6.append(data['total_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 300):
        list_7.append(data['total_exit_time'][ind])

avg_5= np.mean(list_1)
avg_10= np.mean(list_2)
avg_15= np.mean(list_3)
avg_20= np.mean(list_4)
avg_25= np.mean(list_5)
avg_30= np.mean(list_6)
avg_35= np.mean(list_7)

y2.append(avg_5)
y2.append(avg_10)
y2.append(avg_15)
y2.append(avg_20)
y2.append(avg_25)
y2.append(avg_30)
y2.append(avg_35)

y2e.append(np.std(list_1))
y2e.append(np.std(list_2))
y2e.append(np.std(list_3))
y2e.append(np.std(list_4))
y2e.append(np.std(list_5))
y2e.append(np.std(list_6))
y2e.append(np.std(list_7))

# print('y2', y2)

# %%
# y4 initializations
y4=[]
y4e=[]
list_1 = []
avg_1=0
list_2 = []
avg_2=0
list_3 = []
avg_3=0
list_4 = []
avg_4=0
list_5 = []
avg_5=0
list_6 = []
avg_6=0
list_7 = []
avg_7=0

for ind in data.index:
    if(data['max[Obstacle]'][ind] == 0):
        list_1.append(data['avg_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 50):
        list_2.append(data['avg_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 100):
        list_3.append(data['avg_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 150):
        list_4.append(data['avg_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 200):
        list_5.append(data['avg_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 250):
        list_6.append(data['avg_exit_time'][ind])
    if(data['max[Obstacle]'][ind] == 300):
        list_7.append(data['avg_exit_time'][ind])

avg_5= np.mean(list_1)
avg_10= np.mean(list_2)
avg_15= np.mean(list_3)
avg_20= np.mean(list_4)
avg_25= np.mean(list_5)
avg_30= np.mean(list_6)
avg_35= np.mean(list_7)

y4.append(avg_5)
y4.append(avg_10)
y4.append(avg_15)
y4.append(avg_20)
y4.append(avg_25)
y4.append(avg_30)
y4.append(avg_35)

y4e.append(np.std(list_1))
y4e.append(np.std(list_2))
y4e.append(np.std(list_3))
y4e.append(np.std(list_4))
y4e.append(np.std(list_5))
y4e.append(np.std(list_6))
y4e.append(np.std(list_7))

# print('y4', y4)

# %%
# y6 initializations
y6=[]
y6e=[]
list_1 = []
avg_1=0
list_2 = []
avg_2=0
list_3 = []
avg_3=0
list_4 = []
avg_4=0
list_5 = []
avg_5=0
list_6 = []
avg_6=0
list_7 = []
avg_7=0

for ind in data.index:
    if(data['max[Obstacle]'][ind] == 0):
        list_1.append(data['avg_collisions_total'][ind])
    if(data['max[Obstacle]'][ind] == 50):
        list_2.append(data['avg_collisions_total'][ind])
    if(data['max[Obstacle]'][ind] == 100):
        list_3.append(data['avg_collisions_total'][ind])
    if(data['max[Obstacle]'][ind] == 150):
        list_4.append(data['avg_collisions_total'][ind])
    if(data['max[Obstacle]'][ind] == 200):
        list_5.append(data['avg_collisions_total'][ind])
    if(data['max[Obstacle]'][ind] == 250):
        list_6.append(data['avg_collisions_total'][ind])
    if(data['max[Obstacle]'][ind] == 300):
        list_7.append(data['avg_collisions_total'][ind])
avg_5= np.mean(list_1)
avg_10= np.mean(list_2)
avg_15= np.mean(list_3)
avg_20= np.mean(list_4)
avg_25= np.mean(list_5)
avg_30= np.mean(list_6)
avg_35= np.mean(list_7)

y6.append(avg_5)
y6.append(avg_10)
y6.append(avg_15)
y6.append(avg_20)
y6.append(avg_25)
y6.append(avg_30)
y6.append(avg_35)

y6e.append(np.std(list_1))
y6e.append(np.std(list_2))
y6e.append(np.std(list_3))
y6e.append(np.std(list_4))
y6e.append(np.std(list_5))
y6e.append(np.std(list_6))
y6e.append(np.std(list_7))

# print('y6', y6)

# %%
# y8 initializations
y8=[]
y8e=[]
list_1 = []
avg_1=0
list_2 = []
avg_2=0
list_3 = []
avg_3=0
list_4 = []
avg_4=0
list_5 = []
avg_5=0
list_6 = []
avg_6=0
list_7 = []
avg_7=0

for ind in data.index:
    if(data['max[Obstacle]'][ind] == 0):
        list_1.append(data['total_avg_occ_all_time'][ind])
    if(data['max[Obstacle]'][ind] == 50):
        list_2.append(data['total_avg_occ_all_time'][ind])
    if(data['max[Obstacle]'][ind] == 100):
        list_3.append(data['total_avg_occ_all_time'][ind])
    if(data['max[Obstacle]'][ind] == 150):
        list_4.append(data['total_avg_occ_all_time'][ind])
    if(data['max[Obstacle]'][ind] == 200):
        list_5.append(data['total_avg_occ_all_time'][ind])
    if(data['max[Obstacle]'][ind] == 250):
        list_6.append(data['total_avg_occ_all_time'][ind])
    if(data['max[Obstacle]'][ind] == 300):
        list_7.append(data['total_avg_occ_all_time'][ind])
avg_5= np.mean(list_1)
avg_10= np.mean(list_2)
avg_15= np.mean(list_3)
avg_20= np.mean(list_4)
avg_25= np.mean(list_5)
avg_30= np.mean(list_6)
avg_35= np.mean(list_7)

y8.append(avg_5)
y8.append(avg_10)
y8.append(avg_15)
y8.append(avg_20)
y8.append(avg_25)
y8.append(avg_30)
y8.append(avg_35)

y8e.append(np.std(list_1))
y8e.append(np.std(list_2))
y8e.append(np.std(list_3))
y8e.append(np.std(list_4))
y8e.append(np.std(list_5))
y8e.append(np.std(list_6))
y8e.append(np.std(list_7))

# print('y8',y8)

# %%
# y10 initializations
y10=[]
y10e=[]
list_1 = []
avg_1=0
list_2 = []
avg_2=0
list_3 = []
avg_3=0
list_4 = []
avg_4=0
list_5 = []
avg_5=0
list_6 = []
avg_6=0
list_7 = []
avg_7=0

for ind in data.index:
    if(data['max[Obstacle]'][ind] == 0):
        list_1.append(data['evaluation_metric'][ind])
    if(data['max[Obstacle]'][ind] == 50):
        list_2.append(data['evaluation_metric'][ind])
    if(data['max[Obstacle]'][ind] == 100):
        list_3.append(data['evaluation_metric'][ind])
    if(data['max[Obstacle]'][ind] == 150):
        list_4.append(data['evaluation_metric'][ind])
    if(data['max[Obstacle]'][ind] == 200):
        list_5.append(data['evaluation_metric'][ind])
    if(data['max[Obstacle]'][ind] == 250):
        list_6.append(data['evaluation_metric'][ind])
    if(data['max[Obstacle]'][ind] == 300):
        list_7.append(data['evaluation_metric'][ind])
avg_5= np.mean(list_1)
avg_10= np.mean(list_2)
avg_15= np.mean(list_3)
avg_20= np.mean(list_4)
avg_25= np.mean(list_5)
avg_30= np.mean(list_6)
avg_35= np.mean(list_7)

y10.append(avg_5)
y10.append(avg_10)
y10.append(avg_15)
y10.append(avg_20)
y10.append(avg_25)
y10.append(avg_30)
y10.append(avg_35)

y10e.append(np.std(list_1))
y10e.append(np.std(list_2))
y10e.append(np.std(list_3))
y10e.append(np.std(list_4))
y10e.append(np.std(list_5))
y10e.append(np.std(list_6))
y10e.append(np.std(list_7))

# print('y10',y10)

# %%
# building the scatterplots
x2_line=np.array(x2)
y2_line=np.array(y2)
y4_line=np.array(y4)
y6_line=np.array(y6)
y8_line=np.array(y8)
y10_line=np.array(y10)

def f1(x,a,b):
    return a*x+b
def f2(x, a, b, c):
    return a*x*x+b*x+c
def f3(x,a,b):
    return a*np.sqrt(x)+b
def f4(x,a,b,c):
    return a*(b**x)+c
def f5(x,a,b):
    return a*np.log(x)+b

fig=plt.figure(figsize=(30, 12))
gs = GridSpec(nrows=2, ncols=3)

# plot 1, quadratic
ax0 = fig.add_subplot(gs[0, 0])
plt.scatter(x2,y2,s=75)
plt.errorbar(x2,y2,yerr=y2e)
plt.title('Average Total Exit Time Based on Num Obstacles')
plt.xlabel('Number of Obstacles')
plt.ylabel('Average Total Exit Time')

# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y2_line)
# residuals = y2_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
#     f2, quadratic
popt, pcov = curve_fit(f2, x2_line, y2_line)
residuals = y2_line- f2(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y2, f2, r^2: ', r_squared)
plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y2_line)
# residuals = y2_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
# #     f4, exponential
# popt, pcov = curve_fit(f4, x2_line, y2_line)
# residuals = y2_line- f4(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y2_line)
# residuals = y2_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))

# plot 2, quadratic
ax1 = fig.add_subplot(gs[1, 0])
plt.scatter(x2,y4,s=75)
plt.errorbar(x2,y4,yerr=y4e)
plt.title('Mean of Average Exit Time Based on Num Obstacles')
plt.xlabel('Number of Obstacles')
plt.ylabel('Mean of Average Exit Time')

# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y4_line)
# residuals = y4_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
#     f2, quadratic
popt, pcov = curve_fit(f2, x2_line, y4_line)
residuals = y4_line- f2(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y4, f2, r^2: ', r_squared)
plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y4_line)
# residuals = y4_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
# #     f4, exponential
# popt, pcov = curve_fit(f4, x2_line, y4_line)
# residuals = y4_line- f4(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y4_line)
# residuals = y4_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))


# plot 3, exponential
ax2 = fig.add_subplot(gs[0, 1])
plt.scatter(x2,y6,s=75)
plt.errorbar(x2,y6,yerr=y6e)
plt.title('Mean of Average Collisions Based on Num Obstacles')
plt.xlabel('Number of Obstacles')
plt.ylabel('Mean of Average Collisions')

# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y6_line)
# residuals = y6_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
# #     f2, quadratic
# popt, pcov = curve_fit(f2, x2_line, y6_line)
# residuals = y6_line- f2(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y6_line)
# residuals = y6_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
#     f4, exponential
popt, pcov = curve_fit(f4, x2_line, y6_line)
residuals = y6_line- f4(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y6, f4, r^2: ', r_squared)
plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y6_line)
# residuals = y6_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))


# plot 4, exponential
ax3 = fig.add_subplot(gs[1, 1])
plt.scatter(x2,y8,s=75)
plt.errorbar(x2,y8,yerr=y8e)
plt.title('Mean of Average Area Occupancy Based on Num Obstacles')
plt.xlabel('Number of Obstacles')
plt.ylabel('Mean of Average Area Occupancy')

# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y8_line)
# residuals = y8_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
# #     f2, quadratic
# popt, pcov = curve_fit(f2, x2_line, y8_line)
# residuals = y8_line- f2(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y8_line)
# residuals = y8_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
#     f4, exponential
popt, pcov = curve_fit(f4, x2_line, y8_line)
residuals = y8_line- f4(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y8, f4, r^2: ', r_squared)
plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y8_line)
# residuals = y8_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))


# plot 5, quadratic
ax3 = fig.add_subplot(gs[:, 2])
plt.scatter(x2,y10,s=75)
plt.errorbar(x2,y10,yerr=y10e)
plt.title('Average Evaluation Metric Based on Num Obstacles')
plt.xlabel('Number of Obstacles')
plt.ylabel('Average Evaluation Metric')

# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y10_line)
# residuals = y10_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
#     f2, quadratic
popt, pcov = curve_fit(f2, x2_line, y10_line)
residuals = y10_line- f2(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y10, f2, r^2: ', r_squared)
plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y10_line)
# residuals = y10_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
# #     f4, exponential
# popt, pcov = curve_fit(f4, x2_line, y10_line)
# residuals = y10_line- f4(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y10_line)
# residuals = y10_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))
# Out:
# y2, f2, r^2:  0.998821572046064
# y4, f2, r^2:  0.9774215100938968
# y6, f4, r^2:  0.9970280674249085
# y8, f4, r^2:  0.9814415500256451
# y10, f2, r^2:  0.982447656651509
