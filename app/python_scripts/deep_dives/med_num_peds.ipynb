# %%
# this is for the data from the large grid runs ()

# imports and reading csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

import os
import sys

#get correct path for files
__file__ = 'med_num_peds'
absolutepath = os.path.abspath(__file__)
print(absolutepath) #should be MQP/app/python_scripts/deep_dives/med_num_peds
fileDirectory = os.path.dirname(absolutepath)
print(fileDirectory) #should be MQP/app/python_scripts/deep_dives
#Path of parent directory
parentDirectory = os.path.dirname(fileDirectory)
print(parentDirectory) #should be MQP/app/python_scripts
appDirectory = os.path.dirname(parentDirectory)
print(appDirectory) #should be MQP/app
#Navigate to all_data directory
all_data = os.path.join(appDirectory, 'all_data') #the directory going to, change if something different
print(all_data) #should be MQP/app/all_data
pathOutput16 = os.path.join(all_data, 'data_16.csv') #the file reading from, change if something different
print(pathOutput16) #should be MQP/app/all_data/data_16.csv
pathOutput20 = os.path.join(all_data, 'data_20.csv') #the file reading from, change if something different
print(pathOutput20) #should be MQP/app/all_data/data_20.csv
pathOutput24 = os.path.join(all_data, 'data_24.csv') #the file reading from, change if something different
print(pathOutput24) #should be MQP/app/all_data/data_24.csv

data15 = pd.read_csv(pathOutput16)
data16 = pd.read_csv(pathOutput20)
data17 = pd.read_csv(pathOutput24)
# Out:
# /Users/victoriamirecki/Downloads/MQP/app/python_scripts/deep_dives/med_num_peds
# /Users/victoriamirecki/Downloads/MQP/app/python_scripts/deep_dives
# /Users/victoriamirecki/Downloads/MQP/app/python_scripts
# /Users/victoriamirecki/Downloads/MQP/app
# /Users/victoriamirecki/Downloads/MQP/app/all_data
# /Users/victoriamirecki/Downloads/MQP/app/all_data/data_16.csv
# /Users/victoriamirecki/Downloads/MQP/app/all_data/data_20.csv
# /Users/victoriamirecki/Downloads/MQP/app/all_data/data_24.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# med_num_peds in <module>
#      31 print(pathOutput24) #should be MQP/app/all_data/data_24.csv
#      32
# ---> 33 data15 = pd.read_csv(pathOutput16)
#      34 data16 = pd.read_csv(pathOutput20)
#      35 data17 = pd.read_csv(pathOutput24)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/victoriamirecki/Downloads/MQP/app/all_data/data_16.csv'

# %%
# general initializations
# x=['10,10,10,0', '25,25,25,15']
x=[10,25,50]

# %%
# y1 initializations
y1=[]
y1e=[]

avg_1_15=np.mean(data15['total_exit_time'])
avg_1_16=np.mean(data16['total_exit_time'])
avg_1_17=np.mean(data17['total_exit_time'])

y1.append(avg_1_15)
y1.append(avg_1_16)
y1.append(avg_1_17)

y1e.append(np.std(data15['total_exit_time']))
y1e.append(np.std(data16['total_exit_time']))
y1e.append(np.std(data17['total_exit_time']))

# print('y1', y1)

# %%
# y2 initializations
y2=[]
y2e=[]

avg_2_15=np.mean(data15['avg_exit_time'])
avg_2_16=np.mean(data16['avg_exit_time'])
avg_2_17=np.mean(data17['avg_exit_time'])

y2.append(avg_2_15)
y2.append(avg_2_16)
y2.append(avg_2_17)

y2e.append(np.std(data15['avg_exit_time']))
y2e.append(np.std(data16['avg_exit_time']))
y2e.append(np.std(data17['avg_exit_time']))

# print('y2', y2)

# %%
# y3 initializations
y3=[]
y3e=[]

avg_3_15=np.mean(data15['avg_collisions_total'])
avg_3_16=np.mean(data16['avg_collisions_total'])
avg_3_17=np.mean(data17['avg_collisions_total'])

y3.append(avg_3_15)
y3.append(avg_3_16)
y3.append(avg_3_17)

y3e.append(np.std(data15['avg_collisions_total']))
y3e.append(np.std(data16['avg_collisions_total']))
y3e.append(np.std(data17['avg_collisions_total']))

# print('y3', y3)

# %%
# y4 initializations
y4=[]
y4e=[]

avg_4_15=np.mean(data15['total_avg_occ_all_time'])
avg_4_16=np.mean(data16['total_avg_occ_all_time'])
avg_4_17=np.mean(data17['total_avg_occ_all_time'])

y4.append(avg_4_15)
y4.append(avg_4_16)
y4.append(avg_4_17)

y4e.append(np.std(data15['total_avg_occ_all_time']))
y4e.append(np.std(data16['total_avg_occ_all_time']))
y4e.append(np.std(data17['total_avg_occ_all_time']))

# print('y4', y4)

# %%
# y5 initializations
y5=[]
y5e=[]

avg_5_15=np.mean(data15['evaluation_metric'])
avg_5_16=np.mean(data16['evaluation_metric'])
avg_5_17=np.mean(data17['evaluation_metric'])

y5.append(avg_5_15)
y5.append(avg_5_16)
y5.append(avg_5_17)

y5e.append(np.std(data15['evaluation_metric']))
y5e.append(np.std(data16['evaluation_metric']))
y5e.append(np.std(data17['evaluation_metric']))

# print('y5', y5)

# %%
# # building the bar graphs

fig=plt.figure(figsize=(30, 12))
gs = GridSpec(nrows=2, ncols=3)

# plot 1
ax0 = fig.add_subplot(gs[0, 0])
plt.scatter(x,y1,s=75)
plt.errorbar(x,y1,yerr=y1e)
plt.title('Average Total Exit Time Based on Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Average Total Exit Time')

# plot 2
ax1 = fig.add_subplot(gs[1, 0])
plt.scatter(x,y2,s=75)
plt.errorbar(x,y2,yerr=y2e)
plt.title('Mean of Average Exit Time Based on Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Mean of Average Exit Time')

# plot 3
ax2 = fig.add_subplot(gs[0, 1])
plt.scatter(x,y3,s=75)
plt.errorbar(x,y3,yerr=y3e)
plt.title('Mean of Average Collisions Based on Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Mean of Average Collisions')

# plot 4
ax3 = fig.add_subplot(gs[1, 1])
plt.scatter(x,y4,s=75)
plt.errorbar(x,y4,yerr=y4e)
plt.title('Mean of Average Area Occupancy Based on Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Mean of Average Area Occupancy')

# plot 5
ax3 = fig.add_subplot(gs[:, 2])
plt.scatter(x,y5,s=75)
plt.errorbar(x,y5,yerr=y5e)
plt.title('Average Evaluation Metric Based on Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Average Evaluation Metric')
# Out:
# Text(0, 0.5, 'Average Evaluation Metric')
