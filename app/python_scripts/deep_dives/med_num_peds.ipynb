# %%
# this is for the data from the medium num ped runs ()

# imports and reading csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data15 = pd.read_csv(r"C:\Users\allym\Documents\MQP\all_data\data_16.csv")
data16 = pd.read_csv(r"C:\Users\allym\Documents\MQP\all_data\data_20.csv")
data17 = pd.read_csv(r"C:\Users\allym\Documents\MQP\all_data\data_24.csv")

# %%
# general initializations
x=['50x50', '150x150', '300x300']

# %%
# y1 initializations
y1=[]

avg_1_15=sum(data15['total_exit_time'])/len(data15['total_exit_time'])
y1.append(avg_1_15)

avg_1_16=sum(data16['total_exit_time'])/len(data16['total_exit_time'])
y1.append(avg_1_16)

avg_1_17=sum(data17['total_exit_time'])/len(data17['total_exit_time'])
y1.append(avg_1_17)

# print('y1', y1)

# %%
# y2 initializations
y2=[]

avg_2_15=sum(data15['avg_exit_time'])/len(data15['avg_exit_time'])
y2.append(avg_2_15)

avg_2_16=sum(data16['avg_exit_time'])/len(data16['avg_exit_time'])
y2.append(avg_2_16)

avg_2_17=sum(data17['avg_exit_time'])/len(data17['avg_exit_time'])
y2.append(avg_2_17)

# print('y2', y2)

# %%
# y3 initializations
y3=[]

avg_3_15=sum(data15['avg_collisions_total'])/len(data15['avg_collisions_total'])
y3.append(avg_3_15)

avg_3_16=sum(data16['avg_collisions_total'])/len(data16['avg_collisions_total'])
y3.append(avg_3_16)

avg_3_17=sum(data17['avg_collisions_total'])/len(data17['avg_collisions_total'])
y3.append(avg_3_17)

# print('y3', y3)

# %%
# y4 initializations
y4=[]

avg_4_15=sum(data15['total_avg_occ_all_time'])/len(data15['total_avg_occ_all_time'])
y4.append(avg_4_15)

avg_4_16=sum(data16['total_avg_occ_all_time'])/len(data16['total_avg_occ_all_time'])
y4.append(avg_4_16)

avg_4_17=sum(data17['total_avg_occ_all_time'])/len(data17['total_avg_occ_all_time'])
y4.append(avg_4_17)

# print('y4', y4)

# %%
# y5 initializations
y5=[]

avg_5_15=sum(data15['evaluation_metric'])/len(data15['evaluation_metric'])
y5.append(avg_5_15)

avg_5_16=sum(data16['evaluation_metric'])/len(data16['evaluation_metric'])
y5.append(avg_5_16)

avg_5_17=sum(data17['evaluation_metric'])/len(data17['evaluation_metric'])
y5.append(avg_5_17)

# print('y5', y5)

# %%
# building the bar graphs

# plot 1
plt.scatter(x,y1)
plt.title('Average total exit time based on grid size (med num peds)')
plt.xlabel('grid size')
plt.ylabel('Average total exit time')
plt.show()

# plot 2
plt.scatter(x,y2)
plt.title('Mean of average exit time based on grid size (med num peds)')
plt.xlabel('grid size')
plt.ylabel('Mean of average exit time')
plt.show()

# plot 3
plt.scatter(x,y3)
plt.title('Mean of average collisions based on grid size (med num peds)')
plt.xlabel('grid size')
plt.ylabel('Mean of average collisions')
plt.show()

# plot 4
plt.scatter(x,y4)
plt.title('Mean of average area occupancy based on grid size (med num peds)')
plt.xlabel('grid size')
plt.ylabel('Mean of average area occupancy')
plt.show()

# plot 5
plt.scatter(x,y5)
plt.title('Average evaluation metric based on grid size (med num peds)')
plt.xlabel('grid size')
plt.ylabel('Average evaluation metric')
plt.show()

print('y1',y1)
print('y2',y2)
print('y3',y3)
print('y4',y4)
print('y5',y5)
# Out:
# y1 [129.92485714285715, 187.14742857142858, 279.3717142857143]
# y2 [30.838561904761935, 57.917260317460304, 105.29788253968259]
# y3 [12.77943492063489, 4.860952380952386, 1.768549206349204]
# y4 [20.865150360627066, 26.240276476854703, 29.109486334367052]
# y5 [22.75284646476982, 36.53793622155799, 77.95694541166465]
