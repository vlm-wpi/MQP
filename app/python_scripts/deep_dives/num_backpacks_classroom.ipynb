# %%
# this is for the data from stratton hall classroom varying number of
# adults with backpacks from 5-50 in increments of 50 with no other 
# pedestrians and keeping everything else constant

# imports and reading csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from scipy.optimize import curve_fit


data = pd.read_csv(r"C:\Users\allym\Documents\MQP\all_data\data_5.csv")

# %%
# general initializations
x1=data['max[AdultBackpack]']
x2=[5,10,15,20,25,30,35,40,45,50]
y1=data['total_exit_time']
y3=data['avg_exit_time']
y5=data['avg_collisions_total']
y7=data['total_avg_occ_all_time']
y9=data['evaluation_metric']

# %%
# y2 initializations
y2=[]
y2e=[]
list_5 = []
avg_5=0
list_10 = []
avg_10=0
list_15 = []
avg_15=0
list_20 = []
avg_20=0
list_25 = []
avg_25=0
list_30 = []
avg_30=0
list_35 = []
avg_35=0
list_40 = []
avg_40=0
list_45 = []
avg_45=0
list_50 = []
avg_50=0

for ind in data.index:
    if(data['max[AdultBackpack]'][ind] == 5):
        list_5.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 10):
        list_10.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 15):
        list_15.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 20):
        list_20.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 25):
        list_25.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 30):
        list_30.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 35):
        list_35.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 40):
        list_40.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 45):
        list_45.append(data['total_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 50):
        list_50.append(data['total_exit_time'][ind])
avg_5= np.mean(list_5)
avg_10= np.mean(list_10)
avg_15= np.mean(list_15)
avg_20= np.mean(list_20)
avg_25= np.mean(list_25)
avg_30= np.mean(list_30)
avg_35= np.mean(list_35)
avg_40= np.mean(list_40)
avg_45= np.mean(list_45)
avg_50= np.mean(list_50)

y2.append(avg_5)
y2.append(avg_10)
y2.append(avg_15)
y2.append(avg_20)
y2.append(avg_25)
y2.append(avg_30)
y2.append(avg_35)
y2.append(avg_40)
y2.append(avg_45)
y2.append(avg_50)

y2e.append(np.std(list_5))
y2e.append(np.std(list_10))
y2e.append(np.std(list_15))
y2e.append(np.std(list_20))
y2e.append(np.std(list_25))
y2e.append(np.std(list_30))
y2e.append(np.std(list_35))
y2e.append(np.std(list_40))
y2e.append(np.std(list_45))
y2e.append(np.std(list_50))

# print('y2', y2)

# %%
# y4 initializations
y4=[]
y4e=[]
list_5 = []
avg_5=0
list_10 = []
avg_10=0
list_15 = []
avg_15=0
list_20 = []
avg_20=0
list_25 = []
avg_25=0
list_30 = []
avg_30=0
list_35 = []
avg_35=0
list_40 = []
avg_40=0
list_45 = []
avg_45=0
list_50 = []
avg_50=0

for ind in data.index:
    if(data['max[AdultBackpack]'][ind] == 5):
        list_5.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 10):
        list_10.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 15):
        list_15.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 20):
        list_20.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 25):
        list_25.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 30):
        list_30.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 35):
        list_35.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 40):
        list_40.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 45):
        list_45.append(data['avg_exit_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 50):
        list_50.append(data['avg_exit_time'][ind])
avg_5= np.mean(list_5)
avg_10= np.mean(list_10)
avg_15= np.mean(list_15)
avg_20= np.mean(list_20)
avg_25= np.mean(list_25)
avg_30= np.mean(list_30)
avg_35= np.mean(list_35)
avg_40= np.mean(list_40)
avg_45= np.mean(list_45)
avg_50= np.mean(list_50)

y4.append(avg_5)
y4.append(avg_10)
y4.append(avg_15)
y4.append(avg_20)
y4.append(avg_25)
y4.append(avg_30)
y4.append(avg_35)
y4.append(avg_40)
y4.append(avg_45)
y4.append(avg_50)


y4e.append(np.std(list_5))
y4e.append(np.std(list_10))
y4e.append(np.std(list_15))
y4e.append(np.std(list_20))
y4e.append(np.std(list_25))
y4e.append(np.std(list_30))
y4e.append(np.std(list_35))
y4e.append(np.std(list_40))
y4e.append(np.std(list_45))
y4e.append(np.std(list_50))


# print('y4',y4)

# %%
# y6 initializations
y6=[]
y6e=[]
list_5 = []
avg_5=0
list_10 = []
avg_10=0
list_15 = []
avg_15=0
list_20 = []
avg_20=0
list_25 = []
avg_25=0
list_30 = []
avg_30=0
list_35 = []
avg_35=0
list_40 = []
avg_40=0
list_45 = []
avg_45=0
list_50 = []
avg_50=0

for ind in data.index:
    if(data['max[AdultBackpack]'][ind] == 5):
        list_5.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 10):
        list_10.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 15):
        list_15.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 20):
        list_20.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 25):
        list_25.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 30):
        list_30.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 35):
        list_35.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 40):
        list_40.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 45):
        list_45.append(data['avg_collisions_total'][ind])
    if(data['max[AdultBackpack]'][ind] == 50):
        list_50.append(data['avg_collisions_total'][ind])
avg_5= np.mean(list_5)
avg_10= np.mean(list_10)
avg_15= np.mean(list_15)
avg_20= np.mean(list_20)
avg_25= np.mean(list_25)
avg_30= np.mean(list_30)
avg_35= np.mean(list_35)
avg_40= np.mean(list_40)
avg_45= np.mean(list_45)
avg_50= np.mean(list_50)

y6.append(avg_5)
y6.append(avg_10)
y6.append(avg_15)
y6.append(avg_20)
y6.append(avg_25)
y6.append(avg_30)
y6.append(avg_35)
y6.append(avg_40)
y6.append(avg_45)
y6.append(avg_50)


y6e.append(np.std(list_5))
y6e.append(np.std(list_10))
y6e.append(np.std(list_15))
y6e.append(np.std(list_20))
y6e.append(np.std(list_25))
y6e.append(np.std(list_30))
y6e.append(np.std(list_35))
y6e.append(np.std(list_40))
y6e.append(np.std(list_45))
y6e.append(np.std(list_50))


# print('y6',y6)

# %%
# y8 initializations
y8=[]
y8e=[]
list_5 = []
avg_5=0
list_10 = []
avg_10=0
list_15 = []
avg_15=0
list_20 = []
avg_20=0
list_25 = []
avg_25=0
list_30 = []
avg_30=0
list_35 = []
avg_35=0
list_40 = []
avg_40=0
list_45 = []
avg_45=0
list_50 = []
avg_50=0

for ind in data.index:
    if(data['max[AdultBackpack]'][ind] == 5):
        list_5.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 10):
        list_10.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 15):
        list_15.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 20):
        list_20.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 25):
        list_25.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 30):
        list_30.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 35):
        list_35.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 40):
        list_40.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 45):
        list_45.append(data['total_avg_occ_all_time'][ind])
    if(data['max[AdultBackpack]'][ind] == 50):
        list_50.append(data['total_avg_occ_all_time'][ind])
avg_5= np.mean(list_5)
avg_10= np.mean(list_10)
avg_15= np.mean(list_15)
avg_20= np.mean(list_20)
avg_25= np.mean(list_25)
avg_30= np.mean(list_30)
avg_35= np.mean(list_35)
avg_40= np.mean(list_40)
avg_45= np.mean(list_45)
avg_50= np.mean(list_50)

y8.append(avg_5)
y8.append(avg_10)
y8.append(avg_15)
y8.append(avg_20)
y8.append(avg_25)
y8.append(avg_30)
y8.append(avg_35)
y8.append(avg_40)
y8.append(avg_45)
y8.append(avg_50)


y8e.append(np.std(list_5))
y8e.append(np.std(list_10))
y8e.append(np.std(list_15))
y8e.append(np.std(list_20))
y8e.append(np.std(list_25))
y8e.append(np.std(list_30))
y8e.append(np.std(list_35))
y8e.append(np.std(list_40))
y8e.append(np.std(list_45))
y8e.append(np.std(list_50))


# print('y8',y8)

# %%
# y10 initializations
y10=[]
y10e=[]
list_5 = []
avg_5=0
list_10 = []
avg_10=0
list_15 = []
avg_15=0
list_20 = []
avg_20=0
list_25 = []
avg_25=0
list_30 = []
avg_30=0
list_35 = []
avg_35=0
list_40 = []
avg_40=0
list_45 = []
avg_45=0
list_50 = []
avg_50=0

for ind in data.index:
    if(data['max[AdultBackpack]'][ind] == 5):
        list_5.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 10):
        list_10.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 15):
        list_15.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 20):
        list_20.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 25):
        list_25.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 30):
        list_30.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 35):
        list_35.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 40):
        list_40.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 45):
        list_45.append(data['evaluation_metric'][ind])
    if(data['max[AdultBackpack]'][ind] == 50):
        list_50.append(data['evaluation_metric'][ind])
avg_5= np.mean(list_5)
avg_10= np.mean(list_10)
avg_15= np.mean(list_15)
avg_20= np.mean(list_20)
avg_25= np.mean(list_25)
avg_30= np.mean(list_30)
avg_35= np.mean(list_35)
avg_40= np.mean(list_40)
avg_45= np.mean(list_45)
avg_50= np.mean(list_50)

y10.append(avg_5)
y10.append(avg_10)
y10.append(avg_15)
y10.append(avg_20)
y10.append(avg_25)
y10.append(avg_30)
y10.append(avg_35)
y10.append(avg_40)
y10.append(avg_45)
y10.append(avg_50)


y10e.append(np.std(list_5))
y10e.append(np.std(list_10))
y10e.append(np.std(list_15))
y10e.append(np.std(list_20))
y10e.append(np.std(list_25))
y10e.append(np.std(list_30))
y10e.append(np.std(list_35))
y10e.append(np.std(list_40))
y10e.append(np.std(list_45))
y10e.append(np.std(list_50))


# print('y10',y10)

# %%
# building the scatterplots
x2_line=np.array(x2)
y2_line=np.array(y2)
y4_line=np.array(y4)
y6_line=np.array(y6)
y8_line=np.array(y8)
y10_line=np.array(y10)

def f1(x,a,b):
    return a*x+b
def f2(x, a, b, c):
    return a*x*x+b*x+c
def f3(x,a,b):
    return a*np.sqrt(x)+b
def f4(x,a,b,c):
    return a*(b**x)+c
def f5(x,a,b):
    return a*np.log(x)+b

fig=plt.figure(figsize=(30, 12))
gs = GridSpec(nrows=2, ncols=3)

# plot 1, quadratic
ax0 = fig.add_subplot(gs[0, 0])
plt.scatter(x2,y2,s=75)
plt.errorbar(x2,y2,yerr=y2e)
plt.title('Average Total Exit Time Based on Num Backpacks')
plt.xlabel('Number of Backpacks')
plt.ylabel('Average Total Exit Time')
# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y2_line)
# residuals = y2_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
#     f2, quadratic
popt, pcov = curve_fit(f2, x2_line, y2_line)
residuals = y2_line- f2(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y2, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y2_line)
# residuals = y2_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
# #     f4, exponential
# popt, pcov = curve_fit(f4, x2_line, y2_line)
# residuals = y2_line- f4(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y2_line)
# residuals = y2_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y2_line-np.mean(y2_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y2, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))


# plot 2, quadratic
ax1 = fig.add_subplot(gs[1, 0])
plt.scatter(x2,y4,s=75)
plt.errorbar(x2,y4,yerr=y4e)
plt.title('Mean of Average Exit Time Based on Num Backpacks')
plt.xlabel('Number of Backpacks')
plt.ylabel('Mean of Average Exit Time')
# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y4_line)
# residuals = y4_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
#     f2, quadratic
popt, pcov = curve_fit(f2, x2_line, y4_line)
residuals = y4_line- f2(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y4, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y4_line)
# residuals = y4_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
# #     f4, exponential
# popt, pcov = curve_fit(f4, x2_line, y4_line)
# residuals = y4_line- f4(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y4_line)
# residuals = y4_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y4_line-np.mean(y4_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y4, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))

# plot 3, quadratic
ax2 = fig.add_subplot(gs[0, 1])
plt.scatter(x2,y6,s=75)
plt.errorbar(x2,y6,yerr=y6e)
plt.title('Mean of Average Collisions Based on Num Backpacks')
plt.xlabel('Number of Backpacks')
plt.ylabel('Mean of Average Collisions')
# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y6_line)
# residuals = y6_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
#     f2, quadratic
popt, pcov = curve_fit(f2, x2_line, y6_line)
residuals = y6_line- f2(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y6, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y6_line)
# residuals = y6_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
# #     f4, exponential
# popt, pcov = curve_fit(f4, x2_line, y6_line)
# residuals = y6_line- f4(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y6_line)
# residuals = y6_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y6_line-np.mean(y6_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y6, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))


# plot 4, exponential
ax3 = fig.add_subplot(gs[1, 1])
plt.scatter(x2,y8,s=75)
plt.errorbar(x2,y8,yerr=y8e)
plt.title('Mean of Average Area Occupancy Based on Num Backpacks')
plt.xlabel('Number of Backpacks')
plt.ylabel('Mean of Average Area Occupancy')
# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y8_line)
# residuals = y8_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
# #     f2, quadratic
# popt, pcov = curve_fit(f2, x2_line, y8_line)
# residuals = y8_line- f2(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y8_line)
# residuals = y8_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
#     f4, exponential
popt, pcov = curve_fit(f4, x2_line, y8_line)
residuals = y8_line- f4(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y8, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y8_line)
# residuals = y8_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y8_line-np.mean(y8_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y8, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))


# plot 5, exponential
ax3 = fig.add_subplot(gs[:, 2])
plt.scatter(x2,y10,s=75)
plt.errorbar(x2,y10,yerr=y10e)
plt.title('Average Evaluation Metric Based on Num Backpacks')
plt.xlabel('Number of Backpacks')
plt.ylabel('Average Evaluation Metric')
# #     f1, linear
# popt, pcov = curve_fit(f1, x2_line, y10_line)
# residuals = y10_line- f1(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f1, r^2: ', r_squared)
# plt.plot(x2_line, f1(x2_line, *popt))
# #     f2, quadratic
# popt, pcov = curve_fit(f2, x2_line, y10_line)
# residuals = y10_line- f2(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f2, r^2: ', r_squared)
# plt.plot(x2_line, f2(x2_line, *popt))
# #     f3, sqrt
# popt, pcov = curve_fit(f3, x2_line, y10_line)
# residuals = y10_line- f3(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f3, r^2: ', r_squared)
# plt.plot(x2_line, f3(x2_line, *popt))
#     f4, exponential
popt, pcov = curve_fit(f4, x2_line, y10_line)
residuals = y10_line- f4(x2_line, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
r_squared = 1 - (ss_res / ss_tot)
print('y10, f4, r^2: ', r_squared)
# plt.plot(x2_line, f4(x2_line, *popt))
# #     f5, log
# popt, pcov = curve_fit(f5, x2_line, y10_line)
# residuals = y10_line- f5(x2_line, *popt)
# ss_res = np.sum(residuals**2)
# ss_tot = np.sum((y10_line-np.mean(y10_line))**2)
# r_squared = 1 - (ss_res / ss_tot)
# print('y10, f5, r^2: ', r_squared)
# plt.plot(x2_line, f5(x2_line, *popt))
# Out:
# y2, f2, r^2:  0.9983689170189801
# y4, f2, r^2:  0.9997781997657236
# y6, f2, r^2:  0.9997554705802141
# y8, f4, r^2:  0.9997353976956567
# y10, f4, r^2:  0.999918529818942
