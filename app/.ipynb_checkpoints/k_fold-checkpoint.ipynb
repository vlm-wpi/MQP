# %%
# imports and reading csv
import pandas as pd
import numpy as np
k_data = pd.read_csv(r"C:\Users\allym\Documents\MQP\MQP\app\k_fold_fake_data.csv")

# %%
# initializations (can change some of these if you want)
k = 10
sets_of_trials = [[0,49],[50,99]]

# %%
# this will make it automatically loop through the sets of trials
index = k_data.index
for [m,n] in sets_of_trials:
    x = m
    seed = k_data['seed']
    conditionm = seed == m
    seedm_index = index[conditionm]
    conditionn = seed == n
    seedn_index = index[conditionn]
    while ((x<=seedn_index) and (x>=seedm_index)):
    

        # shuffle and split the data into k random groups
        # we do this 100 times to get 100 trials (possible that some of them will be the same)
        # can change the number of trials
        i = 0
        total_good_trials = 0
        total_bad_trials = 0

        while (i < 100):
            good_enough_trials = 0
            bad_more_trials = 0
            shuffled = k_data.sample(frac=1)
            result = np.array_split(shuffled,k)

            # for each group, calculate the average of the evaluation metrics
            for part in result:
                other_eval_sum = 0
                eval_sum = sum(part['evaluation_metric'])
                group_avg = eval_sum/len(part['evaluation_metric'])
        #         print('group average: ',group_avg)

            # calculate the average of the remaining parts
                for other_part in result:
                    if (other_part is not part):
                        other_eval_sum = other_eval_sum + sum(other_part['evaluation_metric'])
                other_avg = other_eval_sum/((k-1)*len(part['evaluation_metric']))
        #         print('other average', other_avg)

            # calculate the percent difference between these values for each
            # if the percent difference is less than 5%, it's good, otherwise, it's bad
            # so add it to the appropriate counter
                percent_difference = abs(group_avg - other_avg)/other_avg
        #         print('percent difference',percent_difference)
                if (percent_difference <= 0.05):
                    good_enough_trials += 1
                    total_good_trials += 1
                elif (percent_difference > 0.05):
                    bad_more_trials += 1
                    total_bad_trials += 1

        #     print('i',i,'good: ' ,good_enough_trials,'bad: ', bad_more_trials)

            i = i + 1

        # total number of trials that are good and bad
        # calculates the percentage of good trials
        # when the percentage of good trials is 95% or greater, we are happy
    print([m,n],'total good trials: ', total_good_trials, 'total bad trials',total_bad_trials)
    percent_good_trials = (total_good_trials/(total_good_trials+total_bad_trials))*100
    print([m,n], percent_good_trials)
    x += 1
# Out:
# [0, 49] total good trials:  755 total bad trials 245
# [0, 49] 75.5
# [0, 49] total good trials:  749 total bad trials 251
# [0, 49] 74.9
# [0, 49] total good trials:  741 total bad trials 259
# [0, 49] 74.1
# [0, 49] total good trials:  752 total bad trials 248
# [0, 49] 75.2
# [0, 49] total good trials:  732 total bad trials 268
# [0, 49] 73.2
# [0, 49] total good trials:  750 total bad trials 250
# [0, 49] 75.0
# [0, 49] total good trials:  772 total bad trials 228
# [0, 49] 77.2
# [0, 49] total good trials:  745 total bad trials 255
# [0, 49] 74.5
# [0, 49] total good trials:  729 total bad trials 271
# [0, 49] 72.89999999999999
# [0, 49] total good trials:  754 total bad trials 246
# [0, 49] 75.4
# [0, 49] total good trials:  760 total bad trials 240
# [0, 49] 76.0
# [0, 49] total good trials:  748 total bad trials 252
# [0, 49] 74.8
# [0, 49] total good trials:  732 total bad trials 268
# [0, 49] 73.2
# [0, 49] total good trials:  759 total bad trials 241
# [0, 49] 75.9
# [0, 49] total good trials:  754 total bad trials 246
# [0, 49] 75.4
# [0, 49] total good trials:  772 total bad trials 228
# [0, 49] 77.2
# [0, 49] total good trials:  752 total bad trials 248
# [0, 49] 75.2
# [0, 49] total good trials:  748 total bad trials 252
# [0, 49] 74.8
# [0, 49] total good trials:  725 total bad trials 275
# [0, 49] 72.5
# [0, 49] total good trials:  739 total bad trials 261
# [0, 49] 73.9
# [0, 49] total good trials:  754 total bad trials 246
# [0, 49] 75.4
# [0, 49] total good trials:  752 total bad trials 248
# [0, 49] 75.2
# [0, 49] total good trials:  750 total bad trials 250
# [0, 49] 75.0
# [0, 49] total good trials:  750 total bad trials 250
# [0, 49] 75.0
# [0, 49] total good trials:  773 total bad trials 227
# [0, 49] 77.3
# [0, 49] total good trials:  743 total bad trials 257
# [0, 49] 74.3
# [0, 49] total good trials:  754 total bad trials 246
# [0, 49] 75.4
# [0, 49] total good trials:  742 total bad trials 258
# [0, 49] 74.2
# [0, 49] total good trials:  739 total bad trials 261
# [0, 49] 73.9
# [0, 49] total good trials:  743 total bad trials 257
# [0, 49] 74.3
# [0, 49] total good trials:  747 total bad trials 253
# [0, 49] 74.7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d7d09e1cdad9> in <module>
#      34                 for other_part in result:
#      35                     if (other_part is not part):
# ---> 36                         other_eval_sum = other_eval_sum + sum(other_part['evaluation_metric'])
#      37                 other_avg = other_eval_sum/((k-1)*len(part['evaluation_metric']))
#      38         #         print('other average', other_avg)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2994                 if isinstance(self.columns, MultiIndex):
#    2995                     return self._getitem_multilevel(key)
# -> 2996                 return self._get_item_cache(key)
#    2997
#    2998         # Do we have a slicer (on rows)?
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    3791
#    3792             loc = self.columns.get_loc(item)
# -> 3793             values = self._mgr.iget(loc)
#    3794             res = self._box_col_values(values, loc).__finalize__(self)
#    3795
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in iget(self, i)
#    1000         Return the data as a SingleBlockManager.
#    1001         """
# -> 1002         block = self.blocks[self.blknos[i]]
#    1003         values = block.iget(self.blklocs[i])
#    1004
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in blknos(self)
#     167         if self._blknos is None:
#     168             # Note: these can be altered by other BlockManager methods.
# --> 169             self._rebuild_blknos_and_blklocs()
#     170
#     171         return self._blknos
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     242             rl = blk.mgr_locs
#     243             new_blknos[rl.indexer] = blkno
# --> 244             new_blklocs[rl.indexer] = np.arange(len(rl))
#     245
#     246         if (new_blknos == -1).any():
#
# KeyboardInterrupt:
