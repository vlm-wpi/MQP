# %%
# imports and reading csv
import pandas as pd
import numpy as np
k_data = pd.read_csv(r"C:\Users\allym\Documents\MQP\MQP\app\k_fold_fake_data.csv")

# %%
# initializations (can change some of these if you want)
k = 10

# %%
# shuffle and split the data into k random groups
# we do this 100 times to get 100 trials (possible that some of them will be the same)
i = 0
total_good_trials = 0
total_bad_trials = 0

while (i < 100):
    good_enough_trials = 0
    bad_more_trials = 0
    shuffled = k_data.sample(frac=1)
    result = np.array_split(shuffled,k)

    # for each group, calculate the average of the evaluation metrics
    for part in result:
        other_eval_sum = 0
        eval_sum = sum(part['evaluation_metric'])
        group_avg = eval_sum/len(part['evaluation_metric'])
#         print('group average: ',group_avg)

    # calculate the average of the remaining parts
        for other_part in result:
            if (other_part is not part):
                other_eval_sum = other_eval_sum + sum(other_part['evaluation_metric'])
        other_avg = other_eval_sum/((k-1)*len(part['evaluation_metric']))
#         print('other average', other_avg)

    # calculate the percent difference between these values for each
    # if the percent difference is less than 5%, it's good, otherwise, it's bad
    # so add it to the appropriate counter
        percent_difference = abs(group_avg - other_avg)/other_avg
#         print('percent difference',percent_difference)
        if (percent_difference <= 0.05):
            good_enough_trials += 1
            total_good_trials += 1
        elif (percent_difference > 0.05):
            bad_more_trials += 1
            total_bad_trials += 1
    
    print('i',i,'good: ' ,good_enough_trials,'bad: ', bad_more_trials)
    print('total good trials: ', total_good_trials, 'total bad trials',total_bad_trials)
    
    i = i + 1
# Out:
# i 0 good:  1 bad:  9
# i 1 good:  1 bad:  9
# i 2 good:  2 bad:  8
# i 3 good:  1 bad:  9
# i 4 good:  3 bad:  7
# i 5 good:  3 bad:  7
# i 6 good:  1 bad:  9
# i 7 good:  2 bad:  8
# i 8 good:  1 bad:  9
# i 9 good:  2 bad:  8
# i 10 good:  3 bad:  7
# i 11 good:  1 bad:  9
# i 12 good:  2 bad:  8
# i 13 good:  2 bad:  8
# i 14 good:  2 bad:  8
# i 15 good:  4 bad:  6
# i 16 good:  3 bad:  7
# i 17 good:  5 bad:  5
# i 18 good:  1 bad:  9
# i 19 good:  5 bad:  5
# i 20 good:  2 bad:  8
# i 21 good:  2 bad:  8
# i 22 good:  3 bad:  7
# i 23 good:  2 bad:  8
# i 24 good:  4 bad:  6
# i 25 good:  3 bad:  7
# i 26 good:  2 bad:  8
# i 27 good:  4 bad:  6
# i 28 good:  2 bad:  8
# i 29 good:  2 bad:  8
# i 30 good:  0 bad:  10
# i 31 good:  2 bad:  8
# i 32 good:  1 bad:  9
# i 33 good:  0 bad:  10
# i 34 good:  1 bad:  9
# i 35 good:  1 bad:  9
# i 36 good:  0 bad:  10
# i 37 good:  0 bad:  10
# i 38 good:  1 bad:  9
# i 39 good:  1 bad:  9
# i 40 good:  0 bad:  10
# i 41 good:  2 bad:  8
# i 42 good:  2 bad:  8
# i 43 good:  1 bad:  9
# i 44 good:  3 bad:  7
# i 45 good:  0 bad:  10
# i 46 good:  1 bad:  9
# i 47 good:  1 bad:  9
# i 48 good:  3 bad:  7
# i 49 good:  1 bad:  9
# i 50 good:  3 bad:  7
# i 51 good:  2 bad:  8
# i 52 good:  2 bad:  8
# i 53 good:  4 bad:  6
# i 54 good:  2 bad:  8
# i 55 good:  3 bad:  7
# i 56 good:  4 bad:  6
# i 57 good:  2 bad:  8
# i 58 good:  1 bad:  9
# i 59 good:  1 bad:  9
# i 60 good:  2 bad:  8
# i 61 good:  2 bad:  8
# i 62 good:  2 bad:  8
# i 63 good:  0 bad:  10
# i 64 good:  4 bad:  6
# i 65 good:  1 bad:  9
# i 66 good:  1 bad:  9
# i 67 good:  2 bad:  8
# i 68 good:  3 bad:  7
# i 69 good:  2 bad:  8
# i 70 good:  3 bad:  7
# i 71 good:  1 bad:  9
# i 72 good:  1 bad:  9
# i 73 good:  3 bad:  7
# i 74 good:  1 bad:  9
# i 75 good:  5 bad:  5
# i 76 good:  1 bad:  9
# i 77 good:  1 bad:  9
# i 78 good:  3 bad:  7
# i 79 good:  2 bad:  8
# i 80 good:  0 bad:  10
# i 81 good:  5 bad:  5
# i 82 good:  3 bad:  7
# i 83 good:  5 bad:  5
# i 84 good:  5 bad:  5
# i 85 good:  6 bad:  4
# i 86 good:  3 bad:  7
# i 87 good:  1 bad:  9
# i 88 good:  1 bad:  9
# i 89 good:  4 bad:  6
# i 90 good:  1 bad:  9
# i 91 good:  1 bad:  9
# i 92 good:  3 bad:  7
# i 93 good:  3 bad:  7
# i 94 good:  2 bad:  8
# i 95 good:  3 bad:  7
# i 96 good:  4 bad:  6
# i 97 good:  2 bad:  8
# i 98 good:  3 bad:  7
# i 99 good:  3 bad:  7
